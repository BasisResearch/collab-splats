# %% [markdown]
# # COLMAP Structure from Motion
#
# *This notebook demonstrates COLMAP structure-from-motion reconstruction from extracted keyframes. COLMAP integration is in progress — this is a stub. For the recommended feedforward reconstruction path, see `02_pointcloud/feedforward_methods`. Prerequisite: `01_preprocessing/keyframe_extraction`.*
#
# **Pipeline:** `frames/` → COLMAP feature extraction → matching → mapping → `colmap/sparse/0/`
#
# **Cache outputs (under `TUTORIAL_CACHE`):**
# - `colmap/sparse/0/cameras.bin`
# - `colmap/sparse/0/images.bin`
# - `colmap/sparse/0/points3D.bin`

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from pathlib import Path

# %%
# %run ../tutorial_config.py

# ── Configuration ─────────────────────────────────────────────────────────────
