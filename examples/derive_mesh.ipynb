# %% [markdown]
# ## Creating a mesh
#
# We can also use the Splatter wrapper class to take an existing nerfstudio model and create a mesh!
# 1. **mesh:** creates a mesh via TSDF fusion
#
# 2. **query_mesh:** uses the trained model to query the mesh and returns a similarity map
#
# 3. **plot_mesh:** enables plotting of mesh features

# %%
import os, sys
from pathlib import Path
from ns_extension.wrapper import Splatter, SplatterConfig
# Out:
# [Taichi] version 1.7.3, llvm 15.0.4, commit 5ec301be, linux, python 3.10.18
# [I 07/17/25 20:30:13.815 244323] [shell.py:_shell_pop_print@23] Graphical python shell detected, using wrapped sys.stdout
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %% [markdown]
# Set paths to the file for running splats

# %%
base_dir = Path('/workspace/fieldwork-data/')
session_dir = base_dir / "rats/2024-07-11/SplatsSD"

# Make the configuration 
splatter_config = SplatterConfig(
    file_path=session_dir / "C0119.MP4",
    method='rade-features',
    frame_proportion=0.25, # Use 25% of the frames within the video (or default to minimum 300 frames)
)

# Initialize the Splatter class
splatter = Splatter(splatter_config)

# Call these to populate the splatter with paths (probably a better way to do this --> maybe save out config)
splatter.preprocess()
splatter.extract_features()
# Out:
# transforms.json already exists at /workspace/fieldwork-data/rats/2024-07-11/environment/C0119/preproc/transforms.json
# To rerun preprocessing, set overwrite=True
# Output already exists for rade-features
# To rerun feature extraction, set overwrite=True

# %% [markdown]
# ### Create a mesh

# %%
splatter.mesh()
# Out:
# Available runs:
# [0] 2025-07-11_171420
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 splatter.mesh()
#
# File /tmp/ns-extension/ns_extension/wrapper/splatter.py:293, in Splatter.mesh(self, features_name, overwrite)
#     287 mesher = Open3DTSDFFusion(
#     288     load_config=Path(self.config['model_path']),
#     289     features_name=features_name,
#     290 )
#     292 # Create the mesh
# --> 293 self.config['mesh_info'] = mesher.main()
#
# File /tmp/ns-extension/ns_extension/utils/mesh.py:1054, in Open3DTSDFFusion.main(self)
#    1051 if not self.output_dir.exists():
#    1052     self.output_dir.mkdir(parents=True)
# -> 1054 _, pipeline, _, _ = eval_setup(self.load_config)
#    1056 assert isinstance(pipeline.model, SplatfactoModel)
#    1058 model: SplatfactoModel = pipeline.model
#
# File /opt/conda/envs/nerfstudio/lib/python3.10/site-packages/nerfstudio/utils/eval_utils.py:90, in eval_setup(config_path, eval_num_rays_per_chunk, test_mode, update_config_callback)
#      74 """Shared setup for loading a saved pipeline for evaluation.
#      75
#      76 Args:
#    (...)
#      87     Loaded config, pipeline module, corresponding checkpoint, and step
#      88 """
#      89 # load save config
# ---> 90 config = yaml.load(config_path.read_text(), Loader=yaml.Loader)
#      91 assert isinstance(config, TrainerConfig)
#      93 config.pipeline.datamanager._target = all_methods[config.method_name].pipeline.datamanager._target
#
# File /opt/conda/envs/nerfstudio/lib/python3.10/pathlib.py:1134, in Path.read_text(self, encoding, errors)
#    1130 """
#    1131 Open the file in text mode, read it, and close the file.
#    1132 """
#    1133 encoding = io.text_encoding(encoding)
# -> 1134 with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1135     return f.read()
#
# File /opt/conda/envs/nerfstudio/lib/python3.10/pathlib.py:1119, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1117 if "b" not in mode:
#    1118     encoding = io.text_encoding(encoding)
# -> 1119 return self._accessor.open(self, mode, buffering, encoding, errors,
#    1120                            newline)
#
# IsADirectoryError: [Errno 21] Is a directory: '/workspace/fieldwork-data/rats/2024-07-11/environment/C0119/rade-features/2025-07-11_171420'
